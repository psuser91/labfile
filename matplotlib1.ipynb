# %% [markdown]
# <a href="https://colab.research.google.com/github/psuser91/labfile/blob/main/Copy_of_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.7.1

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoint = np.array([0,6])
ypoint = np.array([0,250])
plt.plot(xpoint,ypoint)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as pd
xpoint = np.array([1,0])
ypoint = np.array([3,10])
plt.plot(xpoint,ypoint)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as pd
xpoint = np.array([1,8])
ypoint = np.array([3,10])
plt.plot(xpoint,ypoint,'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as pd
xpoint = np.array([1,2,6,8])
ypoint = np.array([3,8,1,10])
plt.plot(xpoint,ypoint)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoint = np.array([3,8,1,10,5,7])
plt.plot(ypoint)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoint = ([3,8,1,10])
plt.plot(ypoint, marker = "o")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoint = ([3,8,1,10])
plt.plot(ypoint, marker = "*")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = [1,2,3]
y = [2,4,1]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = [1,2,3]
y = [2,4,1]
y1 = [1,2,3]
y2 = [1,5,5]
plt.plot(x1,y1, label = 'line1' linestyle = '--' color = 'r')
plt,.plot(x,y1, label = 'line2' linestyle = '--' color = 'y')
plt,.plot
plt.legend()
plt.show()
# Out:
#   File "<ipython-input-22-3ac9c75ae811>", line 7
#     plt.plot(x,y, label = 'line1' linestyle = '--' color = 'r')
#                           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoint = ([3,8,1,10])
plt.plot(ypoint, marker = "o")
plt.show()
